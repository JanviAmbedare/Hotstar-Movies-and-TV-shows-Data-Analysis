# %% [markdown]
# # **PROJECT:- Disney+ HOTSTAR DATA ANALYSIS**

# %% [markdown]
# ## **1. Overview**
#
# This dataset contains metadata of TV Shows and Movies available on Disney+ Hotstar. It includes details such as title, genre, release year, language, content type, and other descriptive attributes.
#
# * Dataset Name :- Disney+ Hotstar Tv and Movie Catalog
# * File Name: hotstar.csv
# * Data source :- Kaggle
# * Dataset link :- [link](https://www.kaggle.com/datasets/goelyash/disney-hotstar-tv-and-movie-catalog)
# * Dataset size :- 1.4 MB

# %% [markdown]
# ### **2. About Dataset Structure and its contains**
# The dataset contains metadata-level information (not streaming content).
# Each row represents one movie or TV show.
#
# **Typical dataset size:**
# * Rows: 6245 entries
# * Columns: 10 attributes
#
# Following is the meaning of each attribute:
#
# 1. **hotstar_id:** ID of tv show and movie.
# 2. **title:** Title/Name of tv show and movie.
# 3. **description:** Short Description describing content.
# 4. **genre:** Genre of content.
# 5. **year:** Release year of content.
# 6. **age_rating:** Age Rating. (as listed)
# 7. **running_time:** Running time of movie.(in minutes)
# 8. **season:** Number of seasons of tv show.
# 9. **episodes:** Number of episodes of tv show.
# 10. **type:** Content is Tv show or Movie.
#
# This files contains 6245 unique tv show and movies.

# %%
import pandas as pd

# %%
datapath = r"hotstar.csv"
or_data = pd.read_csv(datapath) #original dataset 
data = or_data.copy() # copy dataset
data.head(5)
# Out:
#    hotstar_id                                title  \
# 0  1000087439                Sambha - Aajcha Chawa
# 1  1260023113  Cars Toon: Mater And The Ghostlight
# 2  1260103188                Kanmani Rambo Khatija
# 3  1260126754                            Butterfly
# 4  1260018228                           Sister Act
#
#                                          description      genre  year  \
# 0  A young man sets off on a mission to clean up ...     Action  2012
# 1  Mater is haunted by a mysterious blue light th...  Animation  2006
# 2  Unlucky since birth, Rambo finds hope when he ...    Romance  2022
# 3  While trying to rescue her sister's kids from ...   Thriller  2022
# 4  Rene, a lounge singer, decides to stay at a Ch...     Comedy  1992
#
#   age_rating  running_time  seasons  episodes   type
# 0    U/A 16+         141.0      NaN       NaN  movie
# 1          U           7.0      NaN       NaN  movie
# 2    U/A 16+         157.0      NaN       NaN  movie
# 3    U/A 16+         136.0      NaN       NaN  movie
# 4     U/A 7+         100.0      NaN       NaN  movie

# %% [markdown]
# **REMARK:** Hotstar Dataset has 6874 rows and 10 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6874 entries, 0 to 6873
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   hotstar_id    6874 non-null   int64
#  1   title         6874 non-null   object
#  2   description   6874 non-null   object
#  3   genre         6874 non-null   object
#  4   year          6874 non-null   int64
#  5   age_rating    6874 non-null   object
#  6   running_time  4568 non-null   float64
#  7   seasons       2306 non-null   float64
#  8   episodes      2306 non-null   float64
#  9   type          6874 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 537.2+ KB

# %%
data.describe()
# Out:
#          hotstar_id         year  running_time      seasons     episodes
# count  6.874000e+03  6874.000000   4568.000000  2306.000000  2306.000000
# mean   1.059077e+09  2011.718650     98.746716     2.661752   127.366869
# std    4.812666e+08    11.936894     49.411142     4.942716   258.138186
# min    3.000000e+00  1928.000000      1.000000     1.000000     1.000000
# 25%    1.000088e+09  2009.000000     70.000000     1.000000     6.000000
# 50%    1.260008e+09  2016.000000    116.000000     1.000000    22.000000
# 75%    1.260099e+09  2019.000000    135.000000     2.000000   130.750000
# max    1.837059e+09  2023.000000    229.000000    73.000000  3973.000000

# %%
data.isnull().sum()
# Out:
# hotstar_id         0
# title              0
# description        0
# genre              0
# year               0
# age_rating         0
# running_time    2306
# seasons         4568
# episodes        4568
# type               0
# dtype: int64

# %% [markdown]
# **REMARK:** Important column (like title, genre) does not has null value. As per no need to remove any null value, which is in other columns (like seasons, episodes)

# %%
data.describe(include=object)
# Out:
#                 title                                        description  \
# count            6874                                               6874
# unique           6677                                               6815
# top     Rubaru Roshni  Unlucky since birth, Rambo finds hope when he ...
# freq                7                                                  4
#
#         genre age_rating   type
# count    6874       6874   6874
# unique     37          6      2
# top     Drama    U/A 13+  movie
# freq     2043       2980   4568

# %% [markdown]
# **REMARK:** This shows that all titles and description of dataset is not unique

# %%
data.duplicated(['title','description']).sum()
# Out:
# np.int64(16)

# %% [markdown]
# **REMARK:** This shows that there is 16 duplicate value on dataset (means both together are identical)

# %%
#duplicates value
data[data.duplicated(['title','description'], keep=False)].head(10)
# Out:
#       hotstar_id                  title  \
# 2     1260103188  Kanmani Rambo Khatija
# 13    1000228200                Maari 2
# 459   1260068261   Annabelle Sethupathi
# 1507  1260108123                    RRR
# 1510  1000228512          Rubaru Roshni
# 1925  1260047825         Mookuthi Amman
# 1937  1260108122                    RRR
# 2150  1260113147           Vikrant Rona
# 2558  1260108121                    RRR
# 2875  1260103193  Kanmani Rambo Khatija
#
#                                             description    genre  year  \
# 2     Unlucky since birth, Rambo finds hope when he ...  Romance  2022
# 13    Maari, a local don, in his new naughty-turned-...   Action  2018
# 459   A scary journey begins when a small-time thief...   Horror  2021
# 1507  Under the British Raj, two revolutionaries wit...   Action  2022
# 1510  Based in India, traversing three decades, test...    Drama  2019
# 1925  Small-time reporter Engels' life changes drast...    Drama  2020
# 1937  Under the British Raj, two revolutionaries wit...   Action  2022
# 2150  When a series of mysterious events stirs pande...   Action  2022
# 2558  Under the British Raj, two revolutionaries wit...   Action  2022
# 2875  Unlucky since birth, Rambo finds hope when he ...  Romance  2022
#
#      age_rating  running_time  seasons  episodes   type
# 2       U/A 16+         157.0      NaN       NaN  movie
# 13      U/A 13+         140.0      NaN       NaN  movie
# 459           U         134.0      NaN       NaN  movie
# 1507    U/A 16+         177.0      NaN       NaN  movie
# 1510    U/A 16+         110.0      NaN       NaN  movie
# 1925     U/A 7+         134.0      NaN       NaN  movie
# 1937    U/A 16+         177.0      NaN       NaN  movie
# 2150    U/A 16+         145.0      NaN       NaN  movie
# 2558    U/A 16+         178.0      NaN       NaN  movie
# 2875    U/A 16+         157.0      NaN       NaN  movie

# %%
#Droping values having Both 'title'and 'description' duplicate
data = data.drop_duplicates(['title','description'])

# %%
data.duplicated(['title','description']).sum()
# Out:
# np.int64(0)

# %%
data = data.drop(['seasons','episodes'],axis=1)

# %% [markdown]
# **REMARK:** As there is no need to drop any column but in case to reduce dataset we can drop column "seasons" and "episodes".

# %%
column_list = list(data.columns)
column_list
# Out:
# ['hotstar_id',
#  'title',
#  'description',
#  'genre',
#  'year',
#  'age_rating',
#  'running_time',
#  'type']

# %%
#Changing name of column
data.rename({'year':'released_year'},axis=1, inplace= True)

# %%
data.rename({'age_rating':'age_limit'}, axis = 1, inplace = True)
data.columns
# Out:
# Index(['hotstar_id', 'title', 'description', 'genre', 'released_year',
#        'age_limit', 'running_time', 'type'],
#       dtype='object')

# %%
#Sorting data based on year
sorted_data = data.sort_values('released_year',ignore_index=True)
print(f"Oldest : {sorted_data['title'].iloc[0]}, Released year : {sorted_data['released_year'].iloc[0]} and type : {sorted_data['type'].iloc[0]}")
print(f"Newest : {sorted_data['title'].iloc[-1]}, Released year : {sorted_data['released_year'].iloc[-1]} and type : {sorted_data['type'].iloc[0]}")
# Out:
# Oldest : Mickey Mouse Steamboat Willie, Released year : 1928 and type : movie
# Newest : Mahanadhi, Released year : 2023 and type : movie

# %%
#converting csv file to excel for performing visualisation
cleaned_data = data.to_excel("cleaned_data_hotstar.xlsx", index = False)
